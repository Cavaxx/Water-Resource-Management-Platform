# %%
import paho.mqtt.client as mqtt
from pymongo import MongoClient
import json

# MongoDB connection details
mongo_client = MongoClient("mongodb://localhost:27017/")
db = mongo_client["water_management"]  # Replace with your database name
collection = db["sensor_data"]  # Replace with your collection name

# MQTT broker details
mqtt_broker = "localhost"  # Replace with your MQTT broker address
mqtt_port = 1883  # Replace with your MQTT broker port if different

# Topic names
select_topic = "river/select"
result_topic = "river/result"

# Define the callback when a message is received
def on_message(client, userdata, message):
    query = json.loads(message.payload.decode("utf-8"))
    print(f"Received query: {query}")

    # Query MongoDB based on the received message
    result = collection.find(query)

    result_list = []
    for doc in result:
        # Convert ObjectId to string for easier handling
        doc["_id"] = str(doc["_id"])
        result_list.append(doc)

    if result_list:
        print(f"Found documents: {result_list}")
        # Publish the result back to another topic if needed
        client.publish(result_topic, json.dumps(result_list))
    else:
        print("No documents found")
        client.publish(result_topic, "No documents found")

# Set up the MQTT client
client = mqtt.Client()

# Set the on_message callback
client.on_message = on_message

# Connect to the MQTT broker
client.connect(mqtt_broker, mqtt_port)

# Subscribe to the topic
client.subscribe(select_topic)

# Start the MQTT client loop to listen for messages
client.loop_start()

# Keep the script running to listen for messages
print("MQTT client is running and waiting for messages...")
try:
    while True:
        pass  # Keep the script running
except KeyboardInterrupt:
    print("Disconnecting MQTT client...")
    client.loop_stop()
    client.disconnect()
# Out:
# /tmp/ipykernel_1664658/2462317405.py:41: DeprecationWarning: Callback API version 1 is deprecated, update to latest version
#   client = mqtt.Client()
# MQTT client is running and waiting for messages...
# Received query: {'site': 'Zento Novo'}
# Found documents: [{'_id': '667ad7316279b54687e7f04e', 'site': 'Zento Novo', 'timestamp': '2024-06-19 01:00:00', 'value': 1.92, 'latitude': 46.232543, 'longitude': 11.156612, 'unit_of_measure': 'm', 'water_body': 'fossa di Caldaro'}, {'_id': '667ad7316279b54687e7f075', 'site': 'Zento Novo', 'timestamp': '2024-06-19 01:15:00', 'value': 1.92, 'latitude': 46.232543, 'longitude': 11.156612, 'unit_of_measure': 'm', 'water_body': 'fossa di Caldaro'}, {'_id': '667ad7316279b54687e7f092', 'site': 'Zento Novo', 'timestamp': '2024-06-19 01:30:00', 'value': 1.93, 'latitude': 46.232543, 'longitude': 11.156612, 'unit_of_measure': 'm', 'water_body': 'fossa di Caldaro'}, {'_id': '667ad7316279b54687e7f0b5', 'site': 'Zento Novo', 'timestamp': '2024-06-19 01:45:00', 'value': 1.95, 'latitude': 46.232543, 'longitude': 11.156612, 'unit_of_measure': 'm', 'water_body': 'fossa di Caldaro'}, {'_id': '667ad7316279b54687e7f0f2', 'site': 'Zento Novo', 'timestamp': '2024-06-19 02:00:00', 'value': 1.94, 'latitude': 46.232543, 'longitude': 11.156612, 'unit_of_measure': 'm', 'water_body': 'fossa di Caldaro'}, {'_id': '667ad7316279b54687e7f0fa', 'site': 'Zento Novo', 'timestamp': '2024-06-19 02:15:00', 'value': 1.94, 'latitude': 46.232543, 'longitude': 11.156612, 'unit_of_measure': 'm', 'water_body': 'fossa di Caldaro'}, {'_id': '667ad7316279b54687e7f108', 'site': 'Zento Novo', 'timestamp': '2024-06-19 02:30:00', 'value': 1.94, 'latitude': 46.232543, 'longitude': 11.156612, 'unit_of_measure': 'm', 'water_body': 'fossa di Caldaro'}, {'_id': '667ad7316279b54687e7f114', 'site': 'Zento Novo', 'timestamp': '2024-06-19 02:45:00', 'value': 1.94, 'latitude': 46.232543, 'longitude': 11.156612, 'unit_of_measure': 'm', 'water_body': 'fossa di Caldaro'}, {'_id': '667ad7316279b54687e7f139', 'site': 'Zento Novo', 'timestamp': '2024-06-19 03:00:00', 'value': 1.94, 'latitude': 46.232543, 'longitude': 11.156612, 'unit_of_measure': 'm', 'water_body': 'fossa di Caldaro'}, {'_id': '667ad7316279b54687e7f148', 'site': 'Zento Novo', 'timestamp': '2024-06-19 03:15:00', 'value': 1.94, 'latitude': 46.232543, 'longitude': 11.156612, 'unit_of_measure': 'm', 'water_body': 'fossa di Caldaro'}, {'_id': '667ad7316279b54687e7f158', 'site': 'Zento Novo', 'timestamp': '2024-06-19 03:30:00', 'value': 1.95, 'latitude': 46.232543, 'longitude': 11.156612, 'unit_of_measure': 'm', 'water_body': 'fossa di Caldaro'}, {'_id': '667ad7316279b54687e7f177', 'site': 'Zento Novo', 'timestamp': '2024-06-19 03:45:00', 'value': 1.96, 'latitude': 46.232543, 'longitude': 11.156612, 'unit_of_measure': 'm', 'water_body': 'fossa di Caldaro'}, {'_id': '667ad7316279b54687e7f17c', 'site': 'Zento Novo', 'timestamp': '2024-06-19 04:00:00', 'value': 1.97, 'latitude': 46.232543, 'longitude': 11.156612, 'unit_of_measure': 'm', 'water_body': 'fossa di Caldaro'}, {'_id': '667ad7316279b54687e7f193', 'site': 'Zento Novo', 'timestamp': '2024-06-19 04:15:00', 'value': 1.98, 'latitude': 46.232543, 'longitude': 11.156612, 'unit_of_measure': 'm', 'water_body': 'fossa di Caldaro'}, {'_id': '667ad7316279b54687e7f1b0', 'site': 'Zento Novo', 'timestamp': '2024-06-19 04:30:00', 'value': 1.99, 'latitude': 46.232543, 'longitude': 11.156612, 'unit_of_measure': 'm', 'water_body': 'fossa di Caldaro'}, {'_id': '667ad7316279b54687e7f1ba', 'site': 'Zento Novo', 'timestamp': '2024-06-19 04:45:00', 'value': 2.0, 'latitude': 46.232543, 'longitude': 11.156612, 'unit_of_measure': 'm', 'water_body': 'fossa di Caldaro'}, {'_id': '667ad7316279b54687e7f1c7', 'site': 'Zento Novo', 'timestamp': '2024-06-19 05:00:00', 'value': 2.01, 'latitude': 46.232543, 'longitude': 11.156612, 'unit_of_measure': 'm', 'water_body': 'fossa di Caldaro'}, {'_id': '667ad7316279b54687e7f1d2', 'site': 'Zento Novo', 'timestamp': '2024-06-19 05:15:00', 'value': 2.01, 'latitude': 46.232543, 'longitude': 11.156612, 'unit_of_measure': 'm', 'water_body': 'fossa di Caldaro'}, {'_id': '667ad7316279b54687e7f1de', 'site': 'Zento Novo', 'timestamp': '2024-06-19 05:30:00', 'value': 2.02, 'lat ...
# Disconnecting MQTT client...
